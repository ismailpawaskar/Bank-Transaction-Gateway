# %% [markdown]
# # Project 1 - Bank Transaction Gateway

# %%
from openpyxl import load_workbook
import smtplib
wb=load_workbook("C:\\Users\\Ismail\\Desktop\\Data Analytics Internship\\SITIP19-KIIT-Python-FinalProject1-Workbook.xlsx")
sheet=wb['UserDetails']
l1=['Karan Shah','Manan Jain','Kunal Patil','Ajay Ranade','Tushar Shinde']                                # Names
l2=['19091022001','19091022002','19091022003','19091022004','19091022005']                                # User ID
l3=['2019091022IND0345','2019091022IND1453','2019091022IND5647','2019091022IND3455','2019091022IND9823']  # Account No.
flag=1
for i in range(1,4):
    n1=input("Enter your User ID:")
    if n1 in l2:
        flag=1
        
        for i in range(1,4):
            acc=input("\nEnter your Account No.:")
            if acc in l3 and ((n1=='19091022001' and acc=='2019091022IND0345') or (n1=='19091022002' and acc=='2019091022IND1453') or (n1=='19091022003' and acc=='2019091022IND5647') or (n1=='19091022004' and acc=='2019091022IND3455') or (n1=='19091022005' and acc=='2019091022IND9823')):
                flag=1
                print("Verifying.....Please Wait!")
                
                # SMTP code to verify OTP sent on mail
                import math,random                                     
                server=smtplib.SMTP('smtp.gmail.com',port=587)
                server.starttls()
                
                server.login('ismailpawaskar55@gmail.com',input('\nEnter your password:'))
                print("Please Wait....")
                d='1234567890'
                OTP=""
                for i in range(0,4):
                    OTP+=d[math.floor(random.random()*10)]
                server.sendmail("ismailpawaskar55@gmail.com","ismailpawaskar55@gmail.com",OTP)
                print("OTP has been sent to your mail successfully!")
                server.quit()
        
                for i in range(1,4):
                    otp=input("\nEnter the OTP:")
                    if otp==OTP:
                        flag=1
                        print("Successfully Verified OTP")
                                
                                
                        for i in range(1,4):
                            cd=input("\nEnter the transaction you want to do:\n1.Credit(C)\n2.Debit(D)\n")    
                            if cd=='C':
                                flag=1
                                for i in range(1,4):
                                    n=input("\nPlease Enter your name:")
                                    if ((n=='Karan Shah' and n1=='19091022001') or (n=='Manan Jain' and n1=='19091022002') or (n=='Kunal Patil' and n1=='19091022003') or (n=='Ajay Ranade' and n1=='19091022004') or (n=='Tushar Shinde' and n1=='19091022005')):
                                        flag=1
                                        if n=='Karan Shah':
                                            flag=1
                                            bal=sheet['F2'].value
                                            print("Current Balance=",bal)
                                            amt=int(input("Enter the amount to be credited:"))
                                            bal=bal+amt
                                            print("Total Amount=",bal)
                                            sheet['H2']=bal
                                            wb.save("C:\\Users\\Ismail\\Desktop\\Data Analytics Internship\\SITIP19-KIIT-Python-FinalProject1-Workbook.xlsx")
                                
                                        elif n=='Manan Jain':
                                            flag=1
                                            bal=sheet['F3'].value
                                            print("Current Balance=",bal)
                                            amt=int(input("Enter the amount to be credited:"))
                                            bal=bal+amt
                                            print("Total Amount=",bal)
                                            sheet['H3']=bal
                                            wb.save("C:\\Users\\Ismail\\Desktop\\Data Analytics Internship\\SITIP19-KIIT-Python-FinalProject1-Workbook.xlsx")
                                
                                        elif n=='Kunal Patil':
                                            flag=1
                                            bal=sheet['F4'].value
                                            print("Current Balance=",bal)
                                            amt=int(input("Enter the amount to be credited:"))
                                            bal=bal+amt
                                            print("Total Amount=",bal)
                                            sheet['H4']=bal
                                            wb.save("C:\\Users\\Ismail\\Desktop\\Data Analytics Internship\\SITIP19-KIIT-Python-FinalProject1-Workbook.xlsx")
                               
                                        elif n=='Ajay Ranade':
                                            flag=1
                                            bal=sheet['F5'].value
                                            print("Current Balance=",bal)
                                            amt=int(input("Enter the amount to be credited:"))
                                            bal=bal+amt
                                            print("Total Amount=",bal)
                                            sheet['H5']=bal
                                            wb.save("C:\\Users\\Ismail\\Desktop\\Data Analytics Internship\\SITIP19-KIIT-Python-FinalProject1-Workbook.xlsx")
                                
                                        elif n=='Tushar Shinde':
                                            flag=1
                                            bal=sheet['F6'].value
                                            print("Current Balance=",bal)
                                            amt=int(input("Enter the amount to be credited:"))
                                            bal=bal+amt
                                            print("Total Amount=",bal)
                                            sheet['H6']=bal
                                            wb.save("C:\\Users\\Ismail\\Desktop\\Data Analytics Internship\\SITIP19-KIIT-Python-FinalProject1-Workbook.xlsx")
                                        else:
                                            print("Recheck the name you entered")
                                        break
                                    else:
                                        flag=0
                                        print("Invalid name, Enter the name corresponding to your ID")
                                break
                            
                                        
                                 
                                
                            if cd=='D':
                                flag=1
                                for i in range(1,4):
                                    n=input("\nPlease Enter your name:")
                                    if ((n=='Karan Shah' and n1=='19091022001') or (n=='Manan Jain' and n1=='19091022002') or (n=='Kunal Patil' and n1=='19091022003') or (n=='Ajay Ranade' and n1=='19091022004') or (n=='Tushar Shinde' and n1=='19091022005')):
                                        flag=1
                                        if n=='Karan Shah':
                                            flag=1
                                            bal=sheet['F2'].value
                                            print("Current Balance=",bal)
                                            amt=int(input("Enter the amount to be debited:"))
                                            bal=bal-amt
                                            print("Remaining Amount=",bal)
                                            sheet['H2']=bal
                                            wb.save("C:\\Users\\Ismail\\Desktop\\Data Analytics Internship\\SITIP19-KIIT-Python-FinalProject1-Workbook.xlsx")
                                
                                        elif n=='Manan Jain':
                                            flag=1
                                            bal=sheet['F3'].value
                                            print("Current Balance=",bal)
                                            amt=int(input("Enter the amount to be debited:"))
                                            bal=bal-amt
                                            print("Remaining Amount=",bal)
                                            sheet['H3']=bal
                                            wb.save("C:\\Users\\Ismail\\Desktop\\Data Analytics Internship\\SITIP19-KIIT-Python-FinalProject1-Workbook.xlsx")
                                
                                        elif n=='Kunal Patil':
                                            flag=1
                                            bal=sheet['F4'].value
                                            print("Current Balance=",bal)
                                            amt=int(input("Enter the amount to be debited:"))
                                            bal=bal-amt
                                            print("Remaining Amount=",bal)
                                            sheet['H4']=bal
                                            wb.save("C:\\Users\\Ismail\\Desktop\\Data Analytics Internship\\SITIP19-KIIT-Python-FinalProject1-Workbook.xlsx")
                                
                                        elif n=='Ajay Ranade':
                                            flag=1
                                            bal=sheet['F5'].value
                                            print("Current Balance=",bal)
                                            amt=int(input("Enter the amount to be debited:"))
                                            bal=bal-amt
                                            print("Remaining Amount=",bal)
                                            sheet['H5']=bal
                                            wb.save("C:\\Users\\Ismail\\Desktop\\Data Analytics Internship\\SITIP19-KIIT-Python-FinalProject1-Workbook.xlsx")
                                
                                        elif n=='Tushar Shinde':
                                            flag=1
                                            bal=sheet['F6'].value
                                            print("Current Balance=",bal)
                                            amt=int(input("Enter the amount to be debited:"))
                                            bal=bal-amt
                                            print("Remaining Amount=",bal)
                                            sheet['H6']=bal
                                            wb.save("C:\\Users\\Ismail\\Desktop\\Data Analytics Internship\\SITIP19-KIIT-Python-FinalProject1-Workbook.xlsx")
                                        else:
                                            print("Recheck the name you entered")
                                        break
                                    else:
                                        flag=0
                                        print("Invalid name, Enter the name corresponding to your ID")
                                break
                            else:
                                flag=0
                                print("Type Error")
                                print("Invalid input! Enter character from the above 2 options")
                                        
                                
                        break
                    else:
                        flag=0
                        print("Invalid OTP")
                break
            else:
                flag=0
                print("Invalid Account no.")
                
        break
    else:
        flag=0
        print("User doesn't exist")

if flag==0:
    print("\nAccount Blocked (Wrong attempt made 3 times)")
elif flag==1:
    print("\nSuccessful Transaction of Rs.",bal,"completed")
# Out:
# Enter your User ID:67yte
# User doesn't exist
# Enter your User ID:19091022002
#
# Enter your Account No.:456234
# Invalid Account no.
#
# Enter your Account No.:2019091022IND1453
# Verifying.....Please Wait!
#
# Enter your password:ismail55gmail
# Please Wait....
# OTP has been sent to your mail successfully!
#
# Enter the OTP:4399
# Successfully Verified OTP
#
# Enter the transaction you want to do:
# 1.Credit(C)
# 2.Debit(D)
# h
# Type Error
# Invalid input! Enter character from the above 2 options
#
# Enter the transaction you want to do:
# 1.Credit(C)
# 2.Debit(D)
# C
#
# Please Enter your name:Karan Shah
# Invalid name, Enter the name corresponding to your ID
#
# Please Enter your name:Manan Jain
# Current Balance= 1000
# Enter the amount to be credited:500
# Total Amount= 1500
#
# Successful Transaction of Rs. 1500 completed
